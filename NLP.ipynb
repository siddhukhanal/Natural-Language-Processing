# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.txt',sep=';',header=None, names=['text','emotion'])

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
df.isnull().sum()
# Out:
# text       0
# emotion    0
# dtype: int64

# %%
unique_emotions=df['emotion'].unique()
emotion_numbers={}
i=0
for emo in unique_emotions:
    emotion_numbers[emo]=i
    i+=1

df['emotion']=df['emotion'].map(emotion_numbers)

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated        0
# 1  i can go from feeling so hopeless to so damned...        0
# 2   im grabbing a minute to post i feel greedy wrong        1
# 3  i am ever feeling nostalgic about the fireplac...        2
# 4                               i am feeling grouchy        1

# %%
df['text']=df['text'].apply(lambda x:x.lower())

# %%
 import string
def remove_punc(txt):
    return txt.translate(str.maketrans('','',string.punctuation))

# %%
df['text']=df['text'].apply(remove_punc)

# %%
def remove_numbers (txt):
    new=""
    for i in txt:
        if not i.isdigit():
            new=new+1
        return new 
    df['text']=df['text'].apply(remove_numbers)

# %% [markdown]
# ## Removing emojis

# %%
def remove_emojis(txt):
    new=""
    for i in txt:
        if i.isascii():
            new+=i
    return new
df['text']=df['text'].apply(remove_emojis)

# %% [markdown]
# Removing Stopwords

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/siddhu/Desktop/Hello-world/Machine Learning/sklearn-env/lib/python3.10/site-packages (3.9.4)
# Requirement already satisfied: joblib in /home/siddhu/Desktop/Hello-world/Machine Learning/sklearn-env/lib/python3.10/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: click in /home/siddhu/Desktop/Hello-world/Machine Learning/sklearn-env/lib/python3.10/site-packages (from nltk) (8.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/siddhu/Desktop/Hello-world/Machine Learning/sklearn-env/lib/python3.10/site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in /home/siddhu/Desktop/Hello-world/Machine Learning/sklearn-env/lib/python3.10/site-packages (from nltk) (4.68.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /home/siddhu/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/siddhu/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
if "/home/siddhu/nltk_data" not in nltk.data.path:
    nltk.data.path.append("/home/siddhu/nltk_data")

# %%
nltk.download('punkt', download_dir="/home/siddhu/nltk_data")
nltk.download('punkt_tab', download_dir="/home/siddhu/nltk_data")
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/siddhu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/siddhu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/siddhu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words=set(stopwords.words('english'))
len(stop_words)
# Out:
# 198

# %%
df.loc[1]['text']
# Out:
# 'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake'

# %%
def remove(txt):
    words=nltk.word_tokenize(txt)
    cleaned=[]
    for i in words:
        if not i in stop_words:
            cleaned.append(i)
    
    return ' '.join(cleaned)

# %%
nltk.data.path.append("/home/siddhu/nltk_data")

# %%
df['text']=df['text'].apply(remove)

# %%
df.loc[1]['text']
# Out:
# 'go feeling hopeless damned hopeful around someone cares awake'

# %%
df.head()
# Out:
#                                                 text  emotion
# 0                              didnt feel humiliated        0
# 1  go feeling hopeless damned hopeful around some...        0
# 2          im grabbing minute post feel greedy wrong        1
# 3  ever feeling nostalgic fireplace know still pr...        2
# 4                                    feeling grouchy        1

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df['text'],df['emotion'],test_size=0.20,random_state=42)

# %%
X_train
# Out:
# 676      refers course though cant help feeling somehow...
# 12113                im starting feel im suffering fatigue
# 7077     feel like probably would liked book little bit...
# 13005                                  really feel awkward
# 12123    im feeling little grumpy today lame weather te...
#                                ...
# 13418    love leave reader feeling confused slightly de...
# 5390                                         feel delicate
# 860                          starting feel little stressed
# 15795             feel stressed tired worn shape neglected
# 7270         feel someone rude wrongly done something lose
# Name: text, Length: 12800, dtype: object

# %%
X_test
# Out:
# 8756                             ive made week feel beaten
# 4660                              feel strategy worthwhile
# 6095                     feel worthless weak say want find
# 304                                        feel clever nov
# 8241                      im moved ive feeling kind gloomy
#                                ...
# 15578    feel useful pulpit find ironic often question ...
# 5746             dried bladders ready day im feeling brave
# 6395                             feel thrilled matter days
# 7624     woke morning text mr c declaring walking work ...
# 15245                                            feel dumb
# Name: text, Length: 3200, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

# %%
bow_vectorizer=CountVectorizer()

# %%
X_train_bow=bow_vectorizer.fit_transform(X_train)

# %%
X_train
# Out:
# 676      refers course though cant help feeling somehow...
# 12113                im starting feel im suffering fatigue
# 7077     feel like probably would liked book little bit...
# 13005                                  really feel awkward
# 12123    im feeling little grumpy today lame weather te...
#                                ...
# 13418    love leave reader feeling confused slightly de...
# 5390                                         feel delicate
# 860                          starting feel little stressed
# 15795             feel stressed tired worn shape neglected
# 7270         feel someone rude wrongly done something lose
# Name: text, Length: 12800, dtype: object

# %%
X_test_bow=bow_vectorizer.transform(X_test)

# %%
X_test_bow
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 26934 stored elements and shape (3200, 13359)>

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
nb_model=MultinomialNB()

# %%
nb_model.fit(X_train_bow,y_train)
# Out:
# MultinomialNB()

# %%
pred_bow=nb_model.predict(X_test_bow)

# %%
print(accuracy_score(y_test,pred_bow))
# Out:
# 0.7678125

# %%
pred_bow
# Out:
# array([0, 5, 0, ..., 5, 5, 0], shape=(3200,))

# %%
y_test
# Out:
# 8756     0
# 4660     5
# 6095     0
# 304      5
# 8241     0
#         ..
# 15578    5
# 5746     5
# 6395     5
# 7624     5
# 15245    0
# Name: emotion, Length: 3200, dtype: int64

# %%
Tfidf_vectorizer=TfidfVectorizer()

# %%
X_train_tfidf=Tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf=Tfidf_vectorizer.transform(X_test)

# %%
nb_model2=MultinomialNB()
nb_model2.fit(X_train_tfidf,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=nb_model2.predict(X_test_tfidf)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6609375

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model=LogisticRegression(max_iter=1000)

# %%
logistic_model.fit(X_train_tfidf,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
log_pred=logistic_model.predict(X_test_tfidf)

# %%
print(accuracy_score(y_test,log_pred))
# Out:
# 0.8615625
